# %% [markdown]
# ### Wind Statistics
# * 데이터에 변경이 일어나면서 결측치가 있음, 여기서는 연습을 위해 데이터를 보정할 예정
#
# * 데이터는 아래 형식을 따르고 있음
#     > Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL<br>
#     > 61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04<br>
#     > 61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83<br>
#     > 61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71<br>
#
#     * 처음 3개 컬럼은 연도, 월, 일
#     * 남은 12개는 아일랜드에 있는 12개 지역의 풍속 평균
#     * 더 자세한 정보는 [여기](https://github.com/guipsamora/pandas_exercises/blob/dab909ac6fd1d7de96975ebf2136f413222460b3/06_Stats/Wind_Stats/wind.desc)

# %%
# 라이브러리 호출
import pandas as pd
import datetime

# 데이터 불러오기
data_url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data'
# sep에 하나 이상의 공백 문자 지정 >> '\s+'
# 0,1,2 번째 열을 날짜로 파싱 >> parse_dates = [[0,1,2]]
data_df = pd.read_csv(data_url, sep='\s+', parse_dates=[[0,1,2]])

print(data_df.info())
data_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Yr_Mo_Dy  6574 non-null   datetime64[ns]
#  1   RPT       6568 non-null   float64
#  2   VAL       6571 non-null   float64
#  3   ROS       6572 non-null   float64
#  4   KIL       6569 non-null   float64
#  5   SHA       6572 non-null   float64
#  6   BIR       6574 non-null   float64
#  7   DUB       6571 non-null   float64
#  8   CLA       6572 non-null   float64
#  9   MUL       6571 non-null   float64
#  10  CLO       6573 non-null   float64
#  11  BEL       6574 non-null   float64
#  12  MAL       6570 non-null   float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 667.8 KB
# None
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# ...

# %%
# 연도가 2061인 것을 수정
# 해당 데이터는 1961-1978년 동안 수집한 것으로 1978보다 큰 연도는 있을 수 없음
data_df['Yr_Mo_Dy'] = data_df.Yr_Mo_Dy.apply(lambda x: datetime.date(x.year-100, x.month, x.day) if x.year > 1978 else x)

data_df.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
# Yr_Mo_Dy 를 인덱스로 지정
data_df.set_index('Yr_Mo_Dy', inplace=True)

data_df.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %%
# 각 지역마다 NaN 결측치가 몇개가 있는지 확인
print(data_df.isnull().sum())

# 결측치가 아닌 값은 몇개인지
data_df.notnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
# 모든 지역과 시간에 걸친 모든 셀 평균 풍속 구하기
data_df.mean().mean()
# Out:
# 10.227982360836938

# %%
# 'loc_stats' 를 이름으로 한 모든 날짜에 대한 각 지역의 min, max, mean, std 값 구하기

# 그냥 describe를 하면 필요하지 않은 값도 나오므로
display(data_df.describe())
# 필요한 것만 보기
data_df.describe().loc[['min', 'max', 'mean', 'std']]
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     8.000000     3.580000     6.750000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.420000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# ...

# %%
# 'day_stats'를 이름으로해서 행에 모든 날짜, 열에 min, max, mean, std 구하기

# 알고가기
# mean, max, min 등은 axis를 지정할 수 있음
# axis = 0 은 기본값으로 열이 기준 asix = 1 은 행이 기준
day_stats = pd.concat([data_df.min(axis=1), data_df.max(axis=1), data_df.mean(axis=1), data_df.std(axis=1)], axis=1)
day_stats.columns = ['min','max','mean','std']
day_stats
# Out:
#              min    max       mean       std
# Yr_Mo_Dy
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %%
# 각 지역에 대하여 1월 동안의 평균 풍속 구하기
# data_df.열이름 뿐만 아니라, data_df.index로 인덱스 기준 추출도 가능함
# 현재 인덱스는 datetime64 형식이므로 month로 찾을 수 있음
data_df[data_df.index.month == 1].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %%
# 데이터를 각 연도에 대한 것으로 다운 샘플링
# groupby에는 열뿐만 아니라 인덱스 규칙도 넣을 수 있음

# 연도 기준으로 to_period 하기
# DatetimeIndex 에 대하여 'M', 'D' 등으로 다운샘플링 가능
print(data_df.index.to_period('Y'))
print(data_df.index.to_period('M'))
print(data_df.index.to_period('W'))
print(data_df.index.to_period('D'))
print('-'*50)

# 이 period index를 groupby로 쓰기
data_df.groupby(data_df.index.to_period('Y')).mean()
# Out:
# PeriodIndex(['1961', '1961', '1961', '1961', '1961', '1961', '1961', '1961',
#              '1961', '1961',
#              ...
#              '1978', '1978', '1978', '1978', '1978', '1978', '1978', '1978',
#              '1978', '1978'],
#             dtype='period[A-DEC]', name='Yr_Mo_Dy', length=6574)
# PeriodIndex(['1961-01', '1961-01', '1961-01', '1961-01', '1961-01', '1961-01',
#              '1961-01', '1961-01', '1961-01', '1961-01',
#              ...
#              '1978-12', '1978-12', '1978-12', '1978-12', '1978-12', '1978-12',
#              '1978-12', '1978-12', '1978-12', '1978-12'],
#             dtype='period[M]', name='Yr_Mo_Dy', length=6574)
# PeriodIndex(['1960-12-26/1961-01-01', '1961-01-02/1961-01-08',
#              '1961-01-02/1961-01-08', '1961-01-02/1961-01-08',
#              '1961-01-02/1961-01-08', '1961-01-02/1961-01-08',
#              '1961-01-02/1961-01-08', '1961-01-02/1961-01-08',
#              '1961-01-09/1961-01-15', '1961-01-09/1961-01-15',
# ...

# %%
# 각각의 지역에 대한 주간 풍속 min, max, mean, std 확인하기 / 기간은 1961/1/2 ~ 52주간
data_df.resample('W').agg(['min','max','mean','std']).iloc[1:53]
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Yr_Mo_Dy
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
# 1961-03-19   4.92  16.88  11.911429  3.860036   9.46  15.54  13.501429
# ...
