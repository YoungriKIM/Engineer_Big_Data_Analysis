# %%
import pandas as pd

# %% [markdown]
# * [출처](https://www.kaggle.com/code/agileteam/3rd-type1-2-3-1-2)
# * Q. 결측치 데이터(행)을 제거하고, 앞에서부터 60% 데이터만 활용해, 'f1' 컬럼 3사분위 값을 구하시오
# * t1-data1

# %%
d1_path = 'C:/Engineer_Big_Data_Analysis/DATAS/kaggle_BDCKR/t1-data1.csv'
d1_df = pd.read_csv(d1_path)
print(d1_df.shape)
d1_df
# Out:
# (90, 7)
#       id   age city    f1  f2    f4         f5
# 0   id01   2.0   서울   NaN   0  ENFJ  91.297791
# 1   id02   9.0   서울  70.0   1  ENFJ  60.339826
# 2   id03  27.0   서울  61.0   1  ISTJ  17.252986
# 3   id04  75.0   서울   NaN   2  INFP  52.667078
# 4   id05  24.0   서울  85.0   2  ISFJ  29.269869
# ..   ...   ...  ...   ...  ..   ...        ...
# 85  id86   2.0   경기   NaN   0  ESTP  29.269869
# 86  id87  19.0   경기   NaN   1  ISFP  97.381034
# 87  id88  89.0   경기  75.0   0  ESTJ  60.339826
# 88  id89  34.0   경기  66.0   1  ENTJ  33.308999
# 89  id90  54.0   경기   NaN   0  ENTP  29.269869
#
# [90 rows x 7 columns]

# %%
# 결측치 있는 곳 확인
print(d1_df.isna().sum())
# 결측치 버리고
d1_df.dropna(inplace=True)
# 앞에서 60%만 사용하기
d1_df = d1_df.iloc[:int(len(d1_df)*0.6), :]
# f1컬럼의 3사분위 값
d1_df.f1.quantile(0.75)
# Out:
# id       0
# age      0
# city     0
# f1      29
# f2       0
# f4       0
# f5       0
# dtype: int64
# 77.25

# %% [markdown]
# * [출처](https://www.kaggle.com/code/agileteam/3rd-type1-3-3-1-3)
# * Q. 결측치가 제일 큰 값의 컬럼명을 구하시오
# * t1-data1

# %%
d2_path = 'C:/Engineer_Big_Data_Analysis/DATAS/kaggle_BDCKR/t1-data1.csv'
d2_df = pd.read_csv(d2_path)
print(d2_df.shape)
d2_df
# Out:
# (90, 7)
#       id   age city    f1  f2    f4         f5
# 0   id01   2.0   서울   NaN   0  ENFJ  91.297791
# 1   id02   9.0   서울  70.0   1  ENFJ  60.339826
# 2   id03  27.0   서울  61.0   1  ISTJ  17.252986
# 3   id04  75.0   서울   NaN   2  INFP  52.667078
# 4   id05  24.0   서울  85.0   2  ISFJ  29.269869
# ..   ...   ...  ...   ...  ..   ...        ...
# 85  id86   2.0   경기   NaN   0  ESTP  29.269869
# 86  id87  19.0   경기   NaN   1  ISFP  97.381034
# 87  id88  89.0   경기  75.0   0  ESTJ  60.339826
# 88  id89  34.0   경기  66.0   1  ENTJ  33.308999
# 89  id90  54.0   경기   NaN   0  ENTP  29.269869
#
# [90 rows x 7 columns]

# %%
# 결측치 확인
d2_df.isna().sum().idxmax()
# Out:
# 'f1'

# %% [markdown]
# * [출처](https://www.kaggle.com/code/agileteam/3rd-type1-1-3-1-1)
# * Q. 2022년 데이터 중 2022년 중앙값보다 큰 값의 데이터 수
# * t1-data2

# %%
d3_path = 'C:/Engineer_Big_Data_Analysis/DATAS/kaggle_BDCKR/t1-data2.csv'
d3_df = pd.read_csv(d3_path)
print(d3_df.shape)
d3_df
# Out:
# (5, 101)
#     year   0   1   2   3   4   5    6   7   8  ...  90  91  92  93  94  95  \
# 0  2022년  69  37  57  70  40  75    8  67  89  ...  79  56  98  21  14  25
# 1  2023년  52  13  22  70  92  80    8  56  17  ...  62  47  59   6  25  96
# 2  2024년  88  44  32  55  64   8    4   2  62  ...  98  95  40  59  69  71
# 3  2025년  80  97  15   4  74  12  100  60  47  ...  30  11   2  54   9  52
# 4  2026년  64  66  62  56  67  80   90  24  58  ...  93  15  88  67   7  82
#
#    96  97  98  99
# 0  17  10  60  17
# 1  69  87  28  64
# 2  86  53  93  64
# 3  51  81  78  22
# 4   5  61  15  63
#
# [5 rows x 101 columns]

# %%
# 2022년 데이터의 중앙값
# 행렬 바꾸기
d3_df_t = d3_df.T
d3_df_t.columns = d3_df_t.iloc[0]
d3_df_t = d3_df_t.iloc[1:]
display(d3_df_t)

# 2022의 중앙값
d3_df_t['2022년'].median()
# Out:
# year 2022년 2023년 2024년 2025년 2026년
# 0       69    52    88    80    64
# 1       37    13    44    97    66
# 2       57    22    32    15    62
# 3       70    70    55     4    56
# 4       40    92    64    74    67
# ..     ...   ...   ...   ...   ...
# 95      25    96    71    52    82
# 96      17    69    86    51     5
# 97      10    87    53    81    61
# 98      60    28    93    78    15
# 99      17    64    64    22    63
#
# [100 rows x 5 columns]
# 54.5

# %%
d3_df.iloc[0, :].T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Administrator\Anaconda3\Lib\site-packages\pandas\core\nanops.py:760, in nanmedian(values, axis, skipna, mask)
#     759 try:
# --> 760     values = values.astype("f8")
#     761 except ValueError as err:
#     762     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: '2022년'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# c:\Engineer_Big_Data_Analysis\kaggle_BDCKR\case_1\3rd-type1-1~3.ipynb 셀 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Engineer_Big_Data_Analysis/kaggle_BDCKR/case_1/3rd-type1-1~3.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> d3_df.iloc[0, :].T.median()
#
# File c:\Users\Administrator\Anaconda3\Lib\site-packages\pandas\core\generic.py:11917, in NDFrame._add_numeric_operations.<locals>.median(self, axis, skipna, level, numeric_only, **kwargs)
#   11899 @doc(
#   11900     _num_doc,
#   11901     desc="Return the median of the values over the requested axis.",
#    (...)
#   11915     **kwargs,
#   11916 ):
# > 11917     return NDFrame.median(self, axis, skipna, level, numeric_only, **kwargs)
#
# File c:\Users\Administrator\Anaconda3\Lib\site-packages\pandas\core\generic.py:11413, in NDFrame.median(self, axis, skipna, level, numeric_only, **kwargs)
#   11405 def median(
#   11406     self,
#   11407     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11411     **kwargs,
#   11412 ) -> Series | float:
# > 11413     return self._stat_function(
#   11414         "median", nanops.nanmedian, axis, skipna, level, numeric_only, **kwargs
#   11415     )
#
# File c:\Users\Administrator\Anaconda3\Lib\site-packages\pandas\core\generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File c:\Users\Administrator\Anaconda3\Lib\site-packages\pandas\core\series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\Administrator\Anaconda3\Lib\site-packages\pandas\core\nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File c:\Users\Administrator\Anaconda3\Lib\site-packages\pandas\core\nanops.py:763, in nanmedian(values, axis, skipna, mask)
#     760     values = values.astype("f8")
#     761 except ValueError as err:
#     762     # e.g. "could not convert string to float: 'a'"
# --> 763     raise TypeError(str(err)) from err
#     764 if mask is not None:
#     765     values[mask] = np.nan
#
# TypeError: could not convert string to float: '2022년'
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다. 셀의 코드를 검토하여 오류의 가능한 원인을 식별하세요. 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'> 여기 </a> 를 클릭하세요. 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
